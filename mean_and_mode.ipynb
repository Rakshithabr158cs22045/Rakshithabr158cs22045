# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakshithabr158cs22045/Rakshithabr158cs22045/blob/main/mean_and_mode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path='/content/dataset univariate test.xlsx'
df=pd.read_excel(path)
df.head(4)
# Out:
#    sl no  marks
# 0      1     12
# 1      2     34
# 2      3     50
# 3      4     45

# %%
df.mean()
# Out:
# sl no    10.5
# marks    33.9
# dtype: float64

# %%
df.mode()
# Out:
#     sl no  marks
# 0       1   34.0
# 1       2    NaN
# 2       3    NaN
# 3       4    NaN
# 4       5    NaN
# 5       6    NaN
# 6       7    NaN
# 7       8    NaN
# 8       9    NaN
# 9      10    NaN
# 10     11    NaN
# 11     12    NaN
# 12     13    NaN
# 13     14    NaN
# 14     15    NaN
# 15     16    NaN
# 16     17    NaN
# 17     18    NaN
# 18     19    NaN
# 19     20    NaN

# %%
df.median()
# Out:
# sl no    10.5
# marks    34.0
# dtype: float64

# %%
df.max() - df.min()
# Out:
# sl no    19
# marks    38
# dtype: int64

# %%
df.var()
# Out:
# sl no     35.000000
# marks    110.936842
# dtype: float64

# %%
df.std()
# Out:
# sl no     5.916080
# marks    10.532656
# dtype: float64

# %% [markdown]
# multiveriate

# %%
import pandas as pd

# %%
path='/content/dataset multivariate 1.xlsx'
df=pd.read_excel(path)
df.head(7)
# Out:
#    salary  id
# 0     100  11
# 1     200  11
# 2     300  12
# 3     400  13
# 4     100  14

# %%
df.mean()
# Out:
# salary    220.0
# id         12.2
# dtype: float64

# %%
df.mode()
# Out:
#    salary  id
# 0     100  11

# %%
df.median()
# Out:
# salary    200.0
# id         12.0
# dtype: float64

# %%
df.max() - df.min()
# Out:
# salary    300
# id          3
# dtype: int64

# %%
import numpy as np
df_range=np.max(df)-np.min(df)
print("Range:", df_range)
# Out:
# Range: 389

# %%
df.var()
# Out:
# salary    17000.0
# id            1.7
# dtype: float64

# %%
df.std()
# Out:
# salary    130.384048
# id          1.303840
# dtype: float64

# %%
df.corr()
# Out:
#           salary        id
# salary  1.000000  0.117647
# id      0.117647  1.000000

# %%
df.cov()
# Out:
#          salary    id
# salary  17000.0  20.0
# id         20.0   1.7

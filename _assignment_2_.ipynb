# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakshithabr158cs22045/Rakshithabr158cs22045/blob/main/_assignment_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
path='/content/RBI DATA states_wise_population_Income.csv'
df=pd.read_csv(path)

# %%
df.mean(numeric_only=True)
# Out:
# Order ID         5.550204e+08
# Units Sold       5.128710e+03
# Unit Price       2.767613e+02
# Unit Cost        1.910480e+02
# Total Revenue    1.373488e+06
# Total Cost       9.318057e+05
# Total Profit     4.416820e+05
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#     2000-01-INC  2011-12-INC  2001 - LIT  2011- LIT  2001 - POP  2011- POP  \
# 0          6415        22582       47.00      61.80         356        381
# 1          9828        30021       53.56      65.39         541        611
# 2         10345        33695       54.34      66.41         889       1055
# 3         10453        36320       55.52      67.02         901       1097
# 4         10744        36554       56.27      67.16         974       1248
# 5         11862        37180       57.63      67.68        1098       1384
# 6         12369        43463       60.47      69.32        1348       1459
# 7         12803        46734       62.56      70.28        1990       1979
# 8         13020        48366       63.08      72.19        2294       2856
# 9         14268        50316       63.25      72.89        2319       2967
# 10        15260        50859       63.74      74.43        3199       3674
# ...

# %%
df.median(numeric_only=True)
# Out:
# 2000-01-INC        16418.000
# 2011-12-INC        66413.000
# 2001 - LIT            68.975
# 2011- LIT             77.465
# 2001 - POP         20989.500
# 2011- POP          25448.000
# 2001 -SEX_Ratio      934.500
# 2011 -SEX_Ratio      949.000
# 2001 -UNEMP           17.000
# 2011 -UNEMP           20.500
# 2001 -Poverty         21.395
# 2011 -Poverty         15.670
# dtype: float64

# %%
df.max(numeric_only=True) - df.min(numeric_only=True)
# Out:
# 2000-01-INC         43356.00
# 2011-12-INC        188988.00
# 2001 - LIT             43.86
# 2011- LIT              32.20
# 2001 - POP         165842.00
# 2011- POP          199431.00
# 2001 -SEX_Ratio       281.00
# 2011 -SEX_Ratio       266.00
# 2001 -UNEMP            89.00
# 2011 -UNEMP           148.00
# 2001 -Poverty          43.67
# 2011 -Poverty          38.93
# dtype: float64

# %%
df.var(numeric_only=True)
# Out:
# 2000-01-INC        1.038693e+08
# 2011-12-INC        1.677737e+09
# 2001 - LIT         1.243046e+02
# 2011- LIT          7.627658e+01
# 2001 - POP         1.448155e+09
# 2011- POP          2.042126e+09
# 2001 -SEX_Ratio    3.215726e+03
# 2011 -SEX_Ratio    2.820193e+03
# 2001 -UNEMP        4.297974e+02
# 2011 -UNEMP        1.038386e+03
# 2001 -Poverty      1.507782e+02
# 2011 -Poverty      1.229036e+02
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# 2000-01-INC        10191.631200
# 2011-12-INC        40960.182286
# 2001 - LIT            11.149199
# 2011- LIT              8.733646
# 2001 - POP         38054.631775
# 2011- POP          45189.884314
# 2001 -SEX_Ratio       56.707370
# 2011 -SEX_Ratio       53.105485
# 2001 -UNEMP           20.731555
# 2011 -UNEMP           32.223999
# 2001 -Poverty         12.279176
# 2011 -Poverty         11.086188
# dtype: float64

# %% [markdown]
# **2) analyze the multivariate of the data set and example**

# %%
df.cov(numeric_only=True)
# Out:
#                   2000-01-INC   2011-12-INC     2001 - LIT      2011- LIT  \
# 2000-01-INC      1.038693e+08  3.575480e+08   38621.591270   36523.500796
# 2011-12-INC      3.575480e+08  1.677737e+09  146499.182903  146548.234677
# 2001 - LIT       3.862159e+04  1.464992e+05     124.304645      92.963551
# 2011- LIT        3.652350e+04  1.465482e+05      92.963551      76.276577
# 2001 - POP      -1.347596e+08 -5.329334e+08  -83636.155121  -78702.103367
# 2011- POP       -1.633727e+08 -6.461036e+08  -98019.500544  -91810.524143
# 2001 -SEX_Ratio -2.175906e+05 -6.789789e+05    -116.794758    -118.436734
# 2011 -SEX_Ratio -1.446335e+05 -4.875990e+05    -110.704496    -112.209183
# 2001 -UNEMP      8.834281e+04  4.729659e+05      -5.869294      12.633417
# 2011 -UNEMP      4.496710e+04  1.877194e+05     -46.814173      -8.581764
# 2001 -Poverty   -8.088855e+04 -2.855626e+05     -27.310466     -29.393954
# 2011 -Poverty   -5.900883e+04 -2.668223e+05     -23.331891     -23.899417
#
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                  2000-01-INC  2011-12-INC  2001 - LIT  2011- LIT  2001 - POP  \
# 2000-01-INC         1.000000     0.856503    0.339893   0.410330   -0.347463
# 2011-12-INC         0.856503     1.000000    0.320797   0.409660   -0.341904
# 2001 - LIT          0.339893     0.320797    1.000000   0.954714   -0.197126
# 2011- LIT           0.410330     0.409660    0.954714   1.000000   -0.236801
# 2001 - POP         -0.347463    -0.341904   -0.197126  -0.236801    1.000000
# 2011- POP          -0.354727    -0.349059   -0.194548  -0.232625    0.998999
# 2001 -SEX_Ratio    -0.376493    -0.292318   -0.184731  -0.239140    0.075535
# 2011 -SEX_Ratio    -0.267230    -0.224162   -0.186974  -0.241932   -0.013069
# 2001 -UNEMP         0.418115     0.556975   -0.025393   0.069774   -0.221888
# 2011 -UNEMP         0.136922     0.142222   -0.130303  -0.030493   -0.303407
# 2001 -Poverty      -0.646359    -0.567767   -0.199488  -0.274090    0.213448
# ...

# %% [markdown]
# # **Univariate**

# %%
import matplotlib.pyplot as plt
d=pd.read_csv('/content/RBI DATA states_wise_population_Income.csv')
plt.bar(d['2001 -Poverty'], d['2011 -Poverty'])
plt.title("bar plot")
plt.xlabel('2000-01-INC')
plt.ylabel('2011-12-INC')
plt.show()

# %%
import matplotlib.pyplot as plt
d=pd.read_csv('/content/RBI DATA states_wise_population_Income.csv')
plt.boxplot(d['2011 -Poverty'])
plt.title("box plot")
plt.xlabel('2011 -Poverty')
plt.show()

# %%
import pandas as pd
sns.violinplot(d['2011 -Poverty'])
plt.show()

# %%
import matplotlib.pyplot as plt
d=pd.read_csv('/content/RBI DATA states_wise_population_Income.csv')
plt.scatter(d['2011 -Poverty'], d['2001 -Poverty'])
plt.title("scatter")
plt.xlabel('2011 -Poverty')
plt.ylabel('2001 -Poverty')
plt.show()

# %%
#Multivariate function
#Multivariate Distribution Plot (Pair Plot):
import seaborn as sns
import matplotlib.pyplot as plt
# Load example dataset
d=pd.read_csv('/content/RBI DATA states_wise_population_Income.csv')
# Create a pair plot
sns.pairplot(d, hue="2001 -UNEMP")
plt.show()

# %%
#Multivariate Comparison Plot (Grouped Bar Chart):
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
path='/content/RBI DATA states_wise_population_Income.csv'
df=pd.read_csv(path)
# Create a grouped bar chart
sns.catplot(x='2011 -Poverty', y='2001 -Poverty',  hue='2011 -Poverty', kind='bar', data=df)
plt.xlabel("2011 -Poverty")
plt.ylabel("2001 -Poverty")
plt.title("Comparison of 2001 - POP, 2011- POP, and by Group")
plt.show()

# %% [markdown]
# # **dataset 2 **

# %%
import pandas as pd

# %%
import pandas as pd
path='/content/AmazonSalesData.csv'
df=pd.read_csv(path)

# %%
df.mean(numeric_only=True)
# Out:
# Order ID         5.550204e+08
# Units Sold       5.128710e+03
# Unit Price       2.767613e+02
# Unit Cost        1.910480e+02
# Total Revenue    1.373488e+06
# Total Cost       9.318057e+05
# Total Profit     4.416820e+05
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#      Order ID  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 0   114606559      8656.0      109.28      35.84        4870.26     3612.24
# 1   115456712         NaN      437.20     263.33        6279.09     4657.16
# 2   122583663         NaN         NaN        NaN       19103.44    11275.32
# 3   135425221         NaN         NaN        NaN       20404.71    15134.04
# 4   142278373         NaN         NaN        NaN       22312.29    15470.91
# ..        ...         ...         ...        ...            ...         ...
# 95  963392674         NaN         NaN        NaN     4368316.68  3494663.16
# 96  963881480         NaN         NaN        NaN     4647149.58  3521431.68
# 97  972292029         NaN         NaN        NaN     5396577.27  4145955.00
# 98  986435210         NaN         NaN        NaN     5513227.50  4350343.52
# 99  994022214         NaN         NaN        NaN     5997054.98  4509793.96
#
#     Total Profit
# 0        1258.02
# 1        1621.93
# ...

# %%
df.median(numeric_only=True)
# Out:
# Order ID         5.577086e+08
# Units Sold       5.382500e+03
# Unit Price       1.798800e+02
# Unit Cost        1.072750e+02
# Total Revenue    7.523144e+05
# Total Cost       3.635664e+05
# Total Profit     2.907680e+05
# dtype: float64

# %%
df.max(numeric_only=True) - df.min(numeric_only=True)
# Out:
# Order ID         8.794157e+08
# Units Sold       9.801000e+03
# Unit Price       6.589400e+02
# Unit Cost        5.180400e+02
# Total Revenue    5.992185e+06
# Total Cost       4.506182e+06
# Total Profit     1.718664e+06
# dtype: float64

# %%
df.var(numeric_only=True)
# Out:
# Order ID         6.792031e+16
# Units Sold       7.809144e+06
# Unit Price       5.550370e+04
# Unit Cost        3.542232e+04
# Total Revenue    2.131684e+12
# Total Cost       1.174922e+12
# Total Profit     1.923155e+11
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# Order ID         2.606153e+08
# Units Sold       2.794485e+03
# Unit Price       2.355922e+02
# Unit Cost        1.882082e+02
# Total Revenue    1.460029e+06
# Total Cost       1.083938e+06
# Total Profit     4.385379e+05
# dtype: float64

# %% [markdown]
# **2) analyze the multivariate of the data set and example**

# %%
df.cov(numeric_only=True)
# Out:
#                    Order ID    Units Sold    Unit Price     Unit Cost  \
# Order ID       6.792031e+16 -1.623398e+11 -1.172359e+10 -1.045747e+10
# Units Sold    -1.623398e+11  7.809144e+06 -4.640481e+04 -4.850918e+04
# Unit Price    -1.172359e+10 -4.640481e+04  5.550370e+04  4.377593e+04
# Unit Cost     -1.045747e+10 -4.850918e+04  4.377593e+04  3.542232e+04
# Total Revenue -1.197405e+14  1.826973e+09  2.587902e+08  1.966455e+08
# Total Cost    -9.292378e+13  1.135124e+09  2.012054e+08  1.580833e+08
# Total Profit  -2.681668e+13  6.918495e+08  5.758482e+07  3.856216e+07
#
#                Total Revenue    Total Cost  Total Profit
# Order ID       -1.197405e+14 -9.292378e+13 -2.681668e+13
# Units Sold      1.826973e+09  1.135124e+09  6.918495e+08
# Unit Price      2.587902e+08  2.012054e+08  5.758482e+07
# Unit Cost       1.966455e+08  1.580833e+08  3.856216e+07
# Total Revenue   2.131684e+12  1.557145e+12  5.745386e+11
# Total Cost      1.557145e+12  1.174922e+12  3.822231e+11
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                Order ID  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID       1.000000   -0.222907   -0.190941  -0.213201      -0.314688
# Units Sold    -0.222907    1.000000   -0.070486  -0.092232       0.447784
# Unit Price    -0.190941   -0.070486    1.000000   0.987270       0.752360
# Unit Cost     -0.213201   -0.092232    0.987270   1.000000       0.715623
# Total Revenue -0.314688    0.447784    0.752360   0.715623       1.000000
# Total Cost    -0.328944    0.374746    0.787905   0.774895       0.983928
# Total Profit  -0.234638    0.564550    0.557365   0.467214       0.897327
#
#                Total Cost  Total Profit
# Order ID        -0.328944     -0.234638
# Units Sold       0.374746      0.564550
# Unit Price       0.787905      0.557365
# Unit Cost        0.774895      0.467214
# Total Revenue    0.983928      0.897327
# Total Cost       1.000000      0.804091
# Total Profit     0.804091      1.000000

# %%
import matplotlib.pyplot as plt
d=pd.read_csv('/content/AmazonSalesData.csv')
plt.boxplot(d['Order ID'])
plt.title("box plot")
plt.xlabel('Unit Price')
plt.show()

# %%
import pandas as pd
sns.violinplot(d['Order ID'])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
d=pd.read_csv('/content/AmazonSalesData.csv')
plt.bar(d['Unit Price'], d['Total Profit'])
plt.title("BAR PLOT")
plt.xlabel('Unit Price')
plt.ylabel('Total Profit')
plt.show()

# %%
import matplotlib.pyplot as plt
d=pd.read_csv('/content/AmazonSalesData.csv')
plt.scatter(d['Order ID'], d['Unit Price'])
plt.title("scatter")
plt.xlabel('Order ID')
plt.ylabel('Unit Price')
plt.show()

# %%
#Multivariate function
#Multivariate Distribution Plot (Pair Plot):
import seaborn as sns
import matplotlib.pyplot as plt
# Load example dataset
d=pd.read_csv('/AmazonSalesData.csv')
# Create a pair plot
sns.pairplot(d, hue="Unit Price")
plt.show()

# %%
#Multivariate Comparison Plot (Grouped Bar Chart):
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
path='/content/AmazonSalesData.csv'
df=pd.read_csv(path)
# Create a grouped bar chart
sns.catplot(x='Total Cost', y='Unit Cost',  hue='Order ID', kind='bar', data=df)
plt.xlabel("Order ID")
plt.ylabel("Total Profit")
plt.title("Comparison of 2001 - POP, 2011- POP, and by Group")
plt.show()

# %%
import pandas as pd
from scipy import stats
df = pd.read_csv('/content/RBI DATA states_wise_population_Income.csv')
groups = df.groupby('2011 -Poverty')['2001 -Poverty'].apply(list)
f_value, p_value = stats.f_oneway(*groups)
print(f"F-value: {f_value}")
print(f"P-value: {p_value}")
# Out:
# F-value: nan
# P-value: nan
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py:4141: DegenerateDataWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   warnings.warn(stats.DegenerateDataWarning(msg))

# %%
import pandas as pd
from scipy.stats import kruskal
data=pd.read_csv('/content/AmazonSalesData.csv')
h_stat, p_val = kruskal('Total Profit', 'Unit Cost','Order ID')
print(f"kruskal-Wallis Test: H_stat={h_stat}, p_val={p_val}")
# Out:
# kruskal-Wallis Test: H_stat=2.0, p_val=0.36787944117144245

# %%
import pandas as pd
from scipy.stats import chi2_contingency
data=pd.read_csv('/content/AmazonSalesData.csv')
contingency_table=pd.crosstab(data['Total Profit'], data['Unit Cost'])
chi2, p, dof, ex = chi2_contingency(contingency_table)
print(f"chi-square test of independence: chi2={chi2}, p={p}, dof={dof}, expected={ex}")
# Out:
# chi-square test of independence: chi2=1100.0, p=0.40160809610536, dof=1089, expected=[[0.1  0.08 0.13 ... 0.02 0.09 0.12]
#  [0.1  0.08 0.13 ... 0.02 0.09 0.12]
#  [0.1  0.08 0.13 ... 0.02 0.09 0.12]
#  ...
#  [0.1  0.08 0.13 ... 0.02 0.09 0.12]
#  [0.1  0.08 0.13 ... 0.02 0.09 0.12]
#  [0.1  0.08 0.13 ... 0.02 0.09 0.12]]

# %%
import pandas as pd
import scipy.stats as  stats
data=pd.read_csv('/content/AmazonSalesData.csv')
Total_Cost__data=data['Total Profit'].values
t_stat, p_val = stats.ttest_1samp(Total_Cost__data, popmean=0)
print(f"one-sample t-test:t_stat={t_stat}, p_val={p_val}")
# Out:
# one-sample t-test:t_stat=10.071694530615225, p_val=7.631873694039257e-17

# %%
import pandas as pd
from scipy.stats import
multivariate_ttest
def multivariate_t_test(df, Total Profit,Unit Cost):
  t_stat, p_val=multivariate_ttest(df[Total Profit], [dfUnit Cost])
  print("T-statistic:", t_stat)
  print("P-value:",p_val)
  if p_val<0.05:
    print("Reject the null hypothesis")
    else:
      print("Fail to reject the null hypothesis")
# Out:
#   File "<ipython-input-58-dd90e76e7212>", line 2
#     from scipy.stats import
#                            ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
from scipy.stats import norm
#load the dataset
data=pd.read_csv('/content/AmazonSalesData.csv')
#calculate the mean &standard deviation of OrderID
mean_OrderID=data['Order ID'].mean()
std_OrderID=data['Order ID'].std()
#define the value we're interested
value=10000
#calculate the probabality using the standard normal distribution
z_score=(value-mean_OrderID)/std_OrderID
probabality=1-norm.cdf(z_score)
print(f'probabality Order ID greater than ${value}:{probabality:.2%}')
# Out:
# probabality Order ID greater than $10000:98.34%

# %%
import pandas as pd
from scipy.stats import norm
#load the dataset
data=pd.read_csv('/content/RBI DATA states_wise_population_Income.csv')
#calculate the mean &standard deviation of 2011-POP
mean_2011-POP=df['2011-POP'].mean()
std_2011-POP==data['2011- POP '].std()
#define the value we're interested
value=30000
#calculate the probabality using the standard normal distribution
z_score=(value-mean_2011- POP )/std_2011- POP
probabality=1-norm.cdf(z_score)
print(f'probabality 2011- POP  greater than ${value}:{probabality:.3%}')
# Out:
#   File "<ipython-input-49-f7d459980dce>", line 6
#     mean_2011-POP=df['2011-POP'].mean()
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
import pandas as pd
from scipy.stats import norm
#Load Amozon sales data
df=pd.read_csv('')
#Calculate mean and standard devution of sales
mean_sales = df['Sales'].mean()
std_dev_sales=df['Sales'].std()
#Calculate z-score for 50 units
z_score=(50-mean_Sales)/std_dev_sales
#Calculate probability using normal distribution
probability=norm.sf(z_score)*100 #convert to percentage
print(f'probabality Sales greater than ${value}:{probabality:.3%}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sales'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-3c03e8264f8c> in <cell line: 6>()
#       4 df=pd.read_csv('/content/AmazonSalesData.csv')
# ...

# %%
import pandas as pd
from scipy.stats import norm
#load the dataset
data=pd.read_csv('/content/AmazonSalesData.csv')
#calculate the mean &standard deviation of OrderID
mean_OrderID=data['Order ID'].mean()
std_OrderID=data['Order ID'].std()
#define the value we're interested
value=50000
#calculate the probabality using the standard normal distribution
z_score=(value-mean_OrderID)/std_OrderID
probabality=1-norm.cdf(z_score)
print(f'probabality Order ID greater than ${value}:{probabality:.1%}')
# Out:
# probabality Order ID greater than $50000:98.3%

# %%
import pandas as pd
from scipy.stats import norm
df=pd.read_csv('/content/RBI DATA states_wise_population_Income.csv')
state_means=df.groupby('State')['income'].mean()
state_stddevs=df.groupby('State')['income'].std()
income_range=[50000,70000]
z_score=[(income_range[0]-state_mean)/state]

# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakshithabr158cs22045/Rakshithabr158cs22045/blob/main/rakshirakshitha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
path='/content/RBI DATA states_wise_population_Income.csv'
df=pd.read_csv(path)
df.head(6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-001e48c6c60d> in <cell line: 2>()
#       1 path='/content/RBI DATA states_wise_population_Income.csv'
# ----> 2 df=pd.read_csv(path)
#       3 df.head(6)
#
# NameError: name 'pd' is not defined

# %%
df=pd.read_csv('/content/RBI DATA states_wise_population_Income.csv')
df.sum()
# Out:
# States_Union Territories    Andaman and Nicobar IslandsAndhra PradeshAruna...
# 2000-01-INC                                                            630289
# 2011-12-INC                                                           2393360
# 2001 - LIT                                                            2233.94
# 2011- LIT                                                             2503.69
# 2001 - POP                                                            1028302
# 2011- POP                                                             1210203
# 2001 -SEX_Ratio                                                         29724
# 2011 -SEX_Ratio                                                         30255
# 2001 -UNEMP                                                               685
# 2011 -UNEMP                                                               943
# 2001 -Poverty                                                          724.08
# ...

# %%
df.min()
# Out:
# States_Union Territories    Andaman and Nicobar Islands
# 2000-01-INC                                        6415
# 2011-12-INC                                       22582
# 2001 - LIT                                         47.0
# 2011- LIT                                          61.8
# 2001 - POP                                          356
# 2011- POP                                           381
# 2001 -SEX_Ratio                                     777
# 2011 -SEX_Ratio                                     818
# 2001 -UNEMP                                           4
# 2011 -UNEMP                                           3
# 2001 -Poverty                                      3.48
# 2011 -Poverty                                       1.0
# dtype: object

# %%
df.head(11)
# Out:
#        States_Union Territories  2000-01-INC  2011-12-INC  2001 - LIT  \
# 0   Andaman and Nicobar Islands        25047        89642       81.30
# 1                Andhra Pradesh        17195        64773       60.47
# 2             Arunachal Pradesh        15260        71366       54.34
# 3                         Assam        12803        36320       63.25
# 4                         Bihar         6415        22582       47.00
# 5                    Chandigarh        49771       136883       81.94
# 6                  Chhattisgarh        10744        48366       64.66
# 7                         Delhi        40678       161446       57.63
# 8                           Goa        43735       211570       78.18
# 9                       Gujarat        18392        85979       81.67
# 10                      Haryana        25583       106320       82.01
#
#     2011- LIT  2001 - POP  2011- POP  2001 -SEX_Ratio  2011 -SEX_Ratio  \
# ...

# %%
df.tail(9)
# Out:
#    States_Union Territories  2000-01-INC  2011-12-INC  2001 - LIT  2011- LIT  \
# 23               Puducherry        35994       103149       88.80      91.33
# 24                   Punjab        27881        76895       66.59      79.60
# 25                Rajasthan        13020        54637       63.08      72.89
# 26                   Sikkim        16077       130127       81.24      85.85
# 27               Tamil Nadu        20972        89050       69.65      75.84
# 28                  Tripura        15983        50859       68.81      81.42
# 29            Uttar Pradesh         9828        30021       73.45      80.09
# 30              Uttarakhand        15285        85372       73.19      87.22
# 31              West Bengal        16583        53383       56.27      67.68
#
#     2001 - POP  2011- POP  2001 -SEX_Ratio  2011 -SEX_Ratio  2001 -UNEMP  \
# 23         974       1248             1001             1037           40
# ...

# %%
df.count()
# Out:
# States_Union Territories    32
# 2000-01-INC                 32
# 2011-12-INC                 32
# 2001 - LIT                  32
# 2011- LIT                   32
# 2001 - POP                  32
# 2011- POP                   32
# 2001 -SEX_Ratio             32
# 2011 -SEX_Ratio             32
# 2001 -UNEMP                 32
# 2011 -UNEMP                 32
# 2001 -Poverty               32
# 2011 -Poverty               32
# dtype: int64

# %%
df.max()
# Out:
# States_Union Territories    West Bengal
# 2000-01-INC                       49771
# 2011-12-INC                      211570
# 2001 - LIT                        90.86
# 2011- LIT                          94.0
# 2001 - POP                       166198
# 2011- POP                        199812
# 2001 -SEX_Ratio                    1058
# 2011 -SEX_Ratio                    1084
# 2001 -UNEMP                          93
# 2011 -UNEMP                         151
# 2001 -Poverty                     47.15
# 2011 -Poverty                     39.93
# dtype: object

# %%
grouped=df.groupby("2001 - POP")
print(grouped.agg({'2001 -Poverty':'sum'}))
# Out:
#             2001 -Poverty
# 2001 - POP
# 356                 20.99
# 541                 36.55
# 889                 19.47
# 901                  5.75
# 974                 21.67
# 1098                33.47
# 1348                 4.40
# 1990                32.67
# 2294                28.54
# 2319                33.87
# 3199                34.44
# 6078                 7.63
# 8489                10.56
# 10144                3.48
# 13851                8.23
# 20834               30.00
# 21145                8.74
# 24359                6.16
# 26656               36.09
# 26946               32.00
# 31841               12.72
# 36805               47.15
# 50671               14.07
# 52851               20.04
# 56507               15.28
# 60348               37.43
# 62406               21.12
# 76210               15.77
# 80176               27.02
# 82999               42.60
# 96879               25.02
# 166198              31.15

# %%
import pandas as pd
#read CSV file into DataFrame
d=pd.read_csv('/content/RBI DATA states_wise_population_Income.csv')
d['poverty']=d['2011-12-INC'].map(lambda x:x * 1.10)
print(d)
# Out:
#        States_Union Territories  2000-01-INC  2011-12-INC  2001 - LIT  \
# 0   Andaman and Nicobar Islands        25047        89642       81.30
# 1                Andhra Pradesh        17195        64773       60.47
# 2             Arunachal Pradesh        15260        71366       54.34
# 3                         Assam        12803        36320       63.25
# 4                         Bihar         6415        22582       47.00
# 5                    Chandigarh        49771       136883       81.94
# 6                  Chhattisgarh        10744        48366       64.66
# 7                         Delhi        40678       161446       57.63
# 8                           Goa        43735       211570       78.18
# 9                       Gujarat        18392        85979       81.67
# 10                      Haryana        25583       106320       82.01
# 11             Himachal Pradesh        22795        75185       69.14
# ...

# %%
import pandas as pd
filtered_d=pd.read_csv('/content/RBI DATA states_wise_population_Income.csv')
filtered_d=d[d['2001 -Poverty'].map(lambda x:x>=30)]
print(filtered_d)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-319ac55354e4> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 filtered_d=pd.read_csv('/content/RBI DATA states_wise_population_Income.csv')
#       3 filtered_d=d[d['2001 -Poverty'].map(lambda x:x>=30)]
#       4 print(filtered_d)
#
# ...

# %%
import pandas as pd
#read CSV file into DataFrame
d=pd.read_csv('/content/RBI DATA states_wise_population_Income.csv')
d['Salary']=d['2011 -UNEMP'].map(lambda x:x*1.10)
print(d)
# Out:
#        States_Union Territories  2000-01-INC  2011-12-INC  2001 - LIT  \
# 0   Andaman and Nicobar Islands        25047        89642       81.30
# 1                Andhra Pradesh        17195        64773       60.47
# 2             Arunachal Pradesh        15260        71366       54.34
# 3                         Assam        12803        36320       63.25
# 4                         Bihar         6415        22582       47.00
# 5                    Chandigarh        49771       136883       81.94
# 6                  Chhattisgarh        10744        48366       64.66
# 7                         Delhi        40678       161446       57.63
# 8                           Goa        43735       211570       78.18
# 9                       Gujarat        18392        85979       81.67
# 10                      Haryana        25583       106320       82.01
# 11             Himachal Pradesh        22795        75185       69.14
# ...

# %%
from functools import reduce
if not filtered_d['2011- LIT'].empty:
  total=reduce(lambda x,y: x+y, filtered_d['2001 -UNEMP'])
  print(total)
else:
  print("the filtered dataframe is empty, cannot calculate total 2001 -UNEMP")
# Out:
# 198

# %%
import pandas as pd
import matplotlib.pyplot as plt
d=pd.read_csv('/content/RBI DATA states_wise_population_Income.csv')
plt.bar(d['2011- LIT'], d['2011-12-INC'], color='orange')
plt.title("BAR PLOT")
plt.xlabel('2011 - poverty')
plt.ylabel('2011-12-INC')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
d=pd.read_csv('/content/RBI DATA states_wise_population_Income.csv')
plt.plot(d['2011- LIT'],d['2001 - POP'], color='green')
plt.title("LINE PLOT")
plt.xlabel('2011 - poverty')
plt.ylabel('2011-12-INC')
plt.show()

# %%
import matplotlib.pyplot as plt
data=pd.read_csv('/content/RBI DATA states_wise_population_Income.csv')
x=data['2000-01-INC']
y=data['2011- LIT']
plt.fill_between(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Area Chart')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.pie(d['2001 - LIT'],labels=d['2011 -SEX_Ratio'], autopct='%1.1f%%')
plt.title('PIE CHART')
# Out:
# Text(0.5, 1.0, 'PIE CHART')

# %%
import matplotlib.pyplot as plt
d.boxplot(column=['2011 -SEX_Ratio'])
plt.title("box plot")
plt.xlabel('2001 - LIT')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(d['2001 - LIT'], d['2011- LIT'])
plt.title("SCATTER PLOT")
plt.xlabel('2001 -SEX_Ratio')
plt.ylabel('2011 -SEX_Ratio')
plt.show()

# %%
import pandas as pd

# %%
path='/content/AmazonSalesData.csv'
df=pd.read_csv(path)
df.head(8)
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
# 5              Australia and Oceania        Solomon Islands        Baby Food
# 6                 Sub-Saharan Africa                 Angola        Household
# 7                 Sub-Saharan Africa           Burkina Faso       Vegetables
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# ...

# %%
df.sum()
# Out:
# Region            Australia and OceaniaCentral America and the C...
# Country           TuvaluGrenadaRussiaSao Tome and PrincipeRwanda...
# Item Type         Baby FoodCerealOffice SuppliesFruitsOffice Sup...
# Sales Channel     OfflineOnlineOfflineOnlineOfflineOnlineOffline...
# Order Priority    HCLCLCMHMHHHLHCMMCLLLHLHLHMLCLMCCHMLLMLMHMHHHH...
# Order Date        5/28/20108/22/20125/2/20146/20/20142/1/20132/4...
# Order ID                                                55502041236
# Ship Date         6/27/20109/15/20125/8/20147/5/20142/6/20132/21...
# Units Sold                                                   512871
# Unit Price                                                 27676.13
# Unit Cost                                                   19104.8
# Total Revenue                                          137348768.31
# Total Cost                                              93180569.91
# Total Profit                                             44168198.4
# dtype: object

# %%
df.min()
# Out:
# Region                 Asia
# Country             Albania
# Item Type         Baby Food
# Sales Channel       Offline
# Order Priority            C
# Order Date        1/11/2012
# Order ID          114606559
# Ship Date         1/13/2012
# Units Sold              124
# Unit Price             9.33
# Unit Cost              6.92
# Total Revenue       4870.26
# Total Cost          3612.24
# Total Profit        1258.02
# dtype: object

# %%
df.max()
# Out:
# Region            Sub-Saharan Africa
# Country                       Zambia
# Item Type                 Vegetables
# Sales Channel                 Online
# Order Priority                     M
# Order Date                  9/8/2014
# Order ID                   994022214
# Ship Date                   9/7/2016
# Units Sold                      9925
# Unit Price                    668.27
# Unit Cost                     524.96
# Total Revenue             5997054.98
# Total Cost                4509793.96
# Total Profit              1719922.04
# dtype: object

# %%
df.count()
# Out:
# States_Union Territories    32
# 2000-01-INC                 32
# 2011-12-INC                 32
# 2001 - LIT                  32
# 2011- LIT                   32
# 2001 - POP                  32
# 2011- POP                   32
# 2001 -SEX_Ratio             32
# 2011 -SEX_Ratio             32
# 2001 -UNEMP                 32
# 2011 -UNEMP                 32
# 2001 -Poverty               32
# 2011 -Poverty               32
# dtype: int64

# %%
df.head()
# Out:
#       States_Union Territories  2000-01-INC  2011-12-INC  2001 - LIT  \
# 0  Andaman and Nicobar Islands        25047        89642       81.30
# 1               Andhra Pradesh        17195        64773       60.47
# 2            Arunachal Pradesh        15260        71366       54.34
# 3                        Assam        12803        36320       63.25
# 4                        Bihar         6415        22582       47.00
#
#    2011- LIT  2001 - POP  2011- POP  2001 -SEX_Ratio  2011 -SEX_Ratio  \
# 0      86.63         356        381              846              876
# 1      67.02       76210      84581              978              993
# 2      65.39        1098       1384              893              938
# 3      72.19       26656      31206              935              958
# 4      61.80       82999     104099              919              918
#
#    2001 -UNEMP  2011 -UNEMP  2001 -Poverty  2011 -Poverty
# 0           34           54          20.99           1.00
# ...

# %%
df.tail()
# Out:
#    States_Union Territories  2000-01-INC  2011-12-INC  2001 - LIT  2011- LIT  \
# 27               Tamil Nadu        20972        89050       69.65      75.84
# 28                  Tripura        15983        50859       68.81      81.42
# 29            Uttar Pradesh         9828        30021       73.45      80.09
# 30              Uttarakhand        15285        85372       73.19      87.22
# 31              West Bengal        16583        53383       56.27      67.68
#
#     2001 - POP  2011- POP  2001 -SEX_Ratio  2011 -SEX_Ratio  2001 -UNEMP  \
# 27       62406      72147              987              996           20
# 28        3199       3674              948              960           12
# 29      166198     199812              898              912            8
# 30        8489      10086              962              963           22
# 31       80176      91276              934              950           28
#
#     2011 -UNEMP  2001 -Poverty  2011 -Poverty
# ...

# %%
grouped=df.groupby("Country")
print(grouped.agg({'Order Date':'sum'}))
# Out:
#                                         Order Date
# Country
# Albania                                   2/2/2010
# Angola                                   4/23/2011
# Australia               10/27/20156/9/20137/7/2014
# Austria                                  2/23/2015
# Azerbaijan                       2/6/20106/13/2012
# ...                                            ...
# The Gambia      5/26/20121/14/20176/7/20122/3/2014
# Turkmenistan                   12/30/20104/23/2013
# Tuvalu                                   5/28/2010
# United Kingdom                            1/5/2012
# Zambia                                    1/4/2011
#
# [76 rows x 1 columns]

# %%
import pandas as pd
#read CSV file into DataFrame
d=pd.read_csv('/content/AmazonSalesData.csv')
d['poverty']=d['Unit Price'].map(lambda x:x * 1.10)
print(d)
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
import pandas as pd
filtered_d=pd.read_csv('/content/AmazonSalesData.csv')
filtered_d=d[d['Units Sold'].map(lambda x:x>=30)]
print(filtered_d)
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
from functools import reduce
if not filtered_d['Ship Date'].empty:
  total=reduce(lambda x,y: x+y, filtered_d['Unit Price'])
  print(total)
else:
  print("the filtered dataframe is empty, cannot calculate total Unit Price")
# Out:
# 27676.13000000001

# %%
import pandas as pd
#read CSV file into DataFrame
d=pd.read_csv('/content/AmazonSalesData.csv')
d['Order ID']=d['Order ID'].map(lambda x:x*0.10)
print(d)
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.plot(d['Order ID'],d['Ship Date'], color='green')
plt.title("LINE PLOT")
plt.xlabel('Country')
plt.ylabel('Region')
# Out:
# Text(0, 0.5, 'Region')

# %%
import matplotlib.pyplot as plt
data=pd.read_csv('/content/AmazonSalesData.csv')
x=data['Unit Cost']
y=data['Unit Price']
plt.fill_between(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Area Chart')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.bar(d['Order Priority'], d['Region'], color='orange')
plt.title("BAR PLOT")
plt.xlabel('Unit Price')
plt.ylabel('Order ID')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(d['Country'], d['Order ID'], color='red')
plt.title("SCATTER PLOT")
plt.xlabel('Unit Price')
plt.ylabel('Unit Cost')
plt.show()

# %%
import matplotlib.pyplot as plt
d.boxplot(column=['Unit Price'])
plt.title("box plot")
plt.xlabel('Order ID')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.pie(d['Unit Price'],labels=d['Order Date'], autopct='%1.1f%%')
plt.title('PIE CHART')
# Out:
# Text(0.5, 1.0, 'PIE CHART')

# %%
df.min()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c3612c624a3f> in <cell line: 1>()
# ----> 1 df.min()
#
# NameError: name 'df' is not defined

# %%
import pandas  as pd

# %%
Path='/content/sample_data/auto-mpg.csv
Df=pd.read_csv(path)
Print(head.(6))
# Out:
#   File "<ipython-input-7-b84de8635a85>", line 1
#     Path='/content/sample_data/auto-mpg.csv
#          ^
# SyntaxError: unterminated string literal (detected at line 1)
